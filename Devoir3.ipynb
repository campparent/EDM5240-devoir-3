# %% [markdown]
# # Devoir pandas

# %% [markdown]
# On importe ceci comme formule de base

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %% [markdown]
# On change les options d'affichage pour que l'affichage des nombres ne soit pas en notation scientifique

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %% [markdown]
# On se crée une variable pour lire le csv

# %%
info = pd.read_csv("ati.csv")

# %% [markdown]
# Pour se donner un peu une idée de ce qu'a l'air le document

# %%
info
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %% [markdown]
# Comme le nombre de pages est la seule valeur numérale, j'explore le nombre de pages moyens

# %%
info.pages.mean()
# Out:
# 84896.704599979144

# %% [markdown]
# J'observe le nombre de données dans chaque colonne

# %%
info.count()
# Out:
# year               28761
# month              28761
# request_number     28748
# summary_en         28741
# summary_fr         28667
# disposition        28740
# pages              28761
# owner_org          28761
# owner_org_title    28761
# dtype: int64

# %% [markdown]
# Je souhaite connaître combien de demandes d'accès à l'information a été faites pour chaque organisme

# %%
info.owner_org_title.value_counts()
# Out:
# National Defence | Défense nationale                                                                                                                             2605
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1650
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1541
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1323
# Health Canada | Santé Canada                                                                                                                                     1164
# ...

# %% [markdown]
# Je remarque que c'est la Défense Nationale qui suscite le plus de demandes donc j'isole ces données

# %%
nat = info.owner_org_title == "National Defence | Défense nationale"

# %%
info[nat]
# Out:
#        year  month request_number  \
# 9067   2016     10   A-2016-00992
# 9068   2015      7   A-2013-00152
# 9069   2015     10   A-2015-00418
# 9070   2015      6   A-2015-00532
# 9071   2015      8   A-2015-00662
# 9072   2015      8   A-2015-00663
# 9073   2015      8   A-2015-00664
# 9074   2015      8   A-2015-00665
# 9075   2015      7   A-2013-00801
# 9076   2016     12   A-2016-00480
# 9077   2015      7   A-2013-01789
# 9078   2015      7   A-2013-01839
# 9079   2015      7   A-2013-01929
# 9080   2015      7   A-2013-01984
# 9081   2016      8   A-2016-00778
# 9082   2015      8   A-2015-00675
# 9083   2016      7   A-2016-00444
# 9084   2015      8   A-2015-00688
# 9085   2015      8   A-2015-00766
# 9086   2015      8   A-2015-00809
# 9087   2015      8   A-2015-00815
# 9088   2015      8   A-2015-00817
# 9089   2015      8   A-2015-00818
# 9090   2015      8   A-2015-00824
# 9091   2015      8   A-2015-00826
# 9092   2015      3   A-2014-01778
# ...
